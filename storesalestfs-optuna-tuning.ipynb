# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
print("LightGBM version:  {}".format(lgb.__version__))
from sklearn.metrics import mean_squared_error, mean_squared_log_error
import optuna
print("Optuna version:  {}".format(optuna.__version__))
import xgboost as xgb
print("XGBoost version:  {}".format(xgb.__version__))
import catboost as cb
from catboost import CatBoostRegressor, Pool

print("Catboost version:  {}".format(catboost.__version__))

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# LightGBM version:  3.3.2
# Optuna version:  3.4.0
# XGBoost version:  2.0.1
# Catboost version:  1.2.2
# /kaggle/input/store-sales-time-series-forecasting/oil.csv
# /kaggle/input/store-sales-time-series-forecasting/sample_submission.csv
# /kaggle/input/store-sales-time-series-forecasting/holidays_events.csv
# /kaggle/input/store-sales-time-series-forecasting/stores.csv
# /kaggle/input/store-sales-time-series-forecasting/train.csv
# /kaggle/input/store-sales-time-series-forecasting/test.csv
# /kaggle/input/store-sales-time-series-forecasting/transactions.csv

# %% [markdown]
# See Version 2 for tuning of Light GBM.
# Version 3 is for tuning XGBoost.
# Version 4 for XGBoost with categorical.
# Version 5 for Catboost with categorical.

# %%
train = pd.read_csv('/kaggle/input/store-sales-time-series-forecasting/train.csv')

# %%
train.date = pd.to_datetime(train.date, format='%Y-%m-%d')
# split date into seperate columns
train['year'] = train.date.dt.year
train['month'] = train.date.dt.month
train['day'] = train.date.dt.day
# add additional columns based on date
train['dayofweek'] = train.date.dt.dayofweek
train['dayofyear'] = train.date.dt.dayofyear
train['weekofyear'] = train.date.dt.isocalendar().week

# %%
train.weekofyear = train.weekofyear.astype('int8')

# %%
train.head()
# Out:
#    id       date  store_nbr      family  sales  onpromotion  year  month  day  \
# 0   0 2013-01-01          1  AUTOMOTIVE    0.0            0  2013      1    1
# 1   1 2013-01-01          1   BABY CARE    0.0            0  2013      1    1
# 2   2 2013-01-01          1      BEAUTY    0.0            0  2013      1    1
# 3   3 2013-01-01          1   BEVERAGES    0.0            0  2013      1    1
# 4   4 2013-01-01          1       BOOKS    0.0            0  2013      1    1
#
#    dayofweek  dayofyear  weekofyear
# 0          1          1           1
# 1          1          1           1
# 2          1          1           1
# 3          1          1           1
# 4          1          1           1

# %%
# not used for catboost
#label_encoder = LabelEncoder()
#train.family = label_encoder.fit_transform(train.family)

# tell Catboost instead that family is a categorical column
categorical_columns = ['store_nbr', 'family']
# convert categorical columns to dtype string
for feature in categorical_columns:
    train[feature] = train[feature].astype('str')

# %%
columns_to_drop = ['sales','id','date']
X_train = train.loc[train.date < '2017-08-01']
y_train = X_train.sales
X_train = X_train.drop(columns_to_drop, axis = 1)
X_val = train.loc[train.date >= '2017-08-01']
y_val = X_val.sales
X_val = X_val.drop(columns_to_drop, axis = 1)

# %%
train.dtypes
# Out:
# id                      int64
# date           datetime64[ns]
# store_nbr              object
# family                 object
# sales                 float64
# onpromotion             int64
# year                    int32
# month                   int32
# day                     int32
# dayofweek               int32
# dayofyear               int32
# weekofyear               int8
# dtype: object

# %%
train.isna().sum()
# Out:
# id             0
# date           0
# store_nbr      0
# family         0
# sales          0
# onpromotion    0
# year           0
# month          0
# day            0
# dayofweek      0
# dayofyear      0
# weekofyear     0
# dtype: int64

# %%
# use log transformation of target column and then caclulate rsme. This is the same as using rsmle. 

df=pd.DataFrame({'yhat': [5000,2500,500], 'y': [10000,5000,1000]})
df['rmse'] = df.apply(lambda row: mean_squared_error([row['y']], [row['yhat']], squared=False), axis=1)
df['rsmle'] = df.apply(lambda row: mean_squared_log_error([row['y']], [row['yhat']], squared=False), axis=1)
#df['mse'] = df.apply(lambda row: mean_squared_error([row['actual']], [row['predicted']]), axis=1)
df['lnyhat'] = np.log1p(df.yhat)
df['lny'] = np.log1p(df.y)
df['transformback'] = np.expm1(df.lny)
df['ln_rmse'] = df.apply(lambda row: mean_squared_error([row['lny']], [row['lnyhat']], squared=False), axis=1) # the rsme of the log columns equals the rsmle of the original columns
df

# %% [markdown]
# Please read: https://forecastegy.com/posts/xgboost-hyperparameter-tuning-with-optuna/
#
# https://forecastegy.com/posts/catboost-hyperparameter-tuning-guide-with-optuna/

# %%
def objective(trial):
    params = {
        "iterations": 100,
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.5, log=True),
        "depth": trial.suggest_int("depth", 5, 15),
        "subsample": trial.suggest_float("subsample", 0.05, 1.0),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.05, 1.0),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 1, 100),
    }

    model = cb.CatBoostRegressor(**params, cat_features=categorical_columns, silent=True)
    model.fit(X_train, np.log1p(y_train))
    predictions = model.predict(X_val)
    rmse = mean_squared_error(np.log1p(y_val), predictions, squared=False)
    return rmse

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)
# Out:
# [I 2023-11-23 08:18:20,542] A new study created in memory with name: no-name-8e3cb564-0bd0-4e77-a7f0-579d16e6fe74
# [I 2023-11-23 08:19:27,305] Trial 0 finished with value: 1.0323276120778184 and parameters: {'learning_rate': 0.016527729962154927, 'depth': 10, 'subsample': 0.9641307057161292, 'colsample_bylevel': 0.4817036063307967, 'min_data_in_leaf': 48}. Best is trial 0 with value: 1.0323276120778184.
# [I 2023-11-23 08:20:24,662] Trial 1 finished with value: 0.7222041601991667 and parameters: {'learning_rate': 0.18342487162003707, 'depth': 12, 'subsample': 0.32058995747961705, 'colsample_bylevel': 0.7491764722906279, 'min_data_in_leaf': 15}. Best is trial 1 with value: 0.7222041601991667.
# [I 2023-11-23 08:21:20,872] Trial 2 finished with value: 0.9194722074125394 and parameters: {'learning_rate': 0.024745965687658758, 'depth': 10, 'subsample': 0.8641707807673937, 'colsample_bylevel': 0.3888245244096772, 'min_data_in_leaf': 55}. Best is trial 1 with value: 0.7222041601991667.
# [I 2023-11-23 08:22:10,491] Trial 3 finished with value: 0.7309937090730759 and parameters: {'learning_rate': 0.20731964487193813, 'depth': 14, 'subsample': 0.08696136921243638, 'colsample_bylevel': 0.43139906072270034, 'min_data_in_leaf': 85}. Best is trial 1 with value: 0.7222041601991667.
# [I 2023-11-23 08:22:54,787] Trial 4 finished with value: 2.384632027604984 and parameters: {'learning_rate': 0.0011621307508835731, 'depth': 10, 'subsample': 0.22132601810388802, 'colsample_bylevel': 0.8798014946478859, 'min_data_in_leaf': 99}. Best is trial 1 with value: 0.7222041601991667.
# [I 2023-11-23 08:23:25,673] Trial 5 finished with value: 1.5369613340264319 and parameters: {'learning_rate': 0.008004283872893238, 'depth': 5, 'subsample': 0.31297452799380804, 'colsample_bylevel': 0.7699616467618696, 'min_data_in_leaf': 78}. Best is trial 1 with value: 0.7222041601991667.
# [I 2023-11-23 08:24:24,218] Trial 6 finished with value: 1.2633279796382773 and parameters: {'learning_rate': 0.010897564003695983, 'depth': 9, 'subsample': 0.5423834222626556, 'colsample_bylevel': 0.8176775160359818, 'min_data_in_leaf': 7}. Best is trial 1 with value: 0.7222041601991667.
# [I 2023-11-23 08:26:17,659] Trial 7 finished with value: 0.7181391734387009 and parameters: {'learning_rate': 0.2447719837330802, 'depth': 15, 'subsample': 0.498219948361003, 'colsample_bylevel': 0.6924214906024062, 'min_data_in_leaf': 19}. Best is trial 7 with value: 0.7181391734387009.
# [I 2023-11-23 08:27:15,200] Trial 8 finished with value: 0.8545333161395914 and parameters: {'learning_rate': 0.033813616910294164, 'depth': 13, 'subsample': 0.8163792315762969, 'colsample_bylevel': 0.3248173388002562, 'min_data_in_leaf': 30}. Best is trial 7 with value: 0.7181391734387009.
# [I 2023-11-23 08:28:13,515] Trial 9 finished with value: 2.1620176110677716 and parameters: {'learning_rate': 0.0024350926770491635, 'depth': 6, 'subsample': 0.8848652006016847, 'colsample_bylevel': 0.9809891580416973, 'min_data_in_leaf': 39}. Best is trial 7 with value: 0.7181391734387009.
# [I 2023-11-23 08:28:47,202] Trial 10 finished with value: 0.7562766848840197 and parameters: {'learning_rate': 0.3506935197861468, 'depth': 15, 'subsample': 0.5829900315096752, 'colsample_bylevel': 0.1917011105452484, 'min_data_in_leaf': 1}. Best is trial 7 with value: 0.7181391734387009.
# [I 2023-11-23 08:29:44,370] Trial 11 finished with value: 0.7413813032758257 and parameters: {'learning_rate': 0.11542330512187032, 'depth': 12, 'subsample': 0.378735512617997, 'colsample_bylevel': 0.6440993178811548, 'min_data_in_leaf': 20}. Best is trial 7 with value: 0.7181391734387009.
# [I 2023-11-23 08:30:45,174] Trial 12 finished with value: 0.7465206033281719 and parameters: {'learning_rate': 0.09449364646332477, 'depth': 12, 'subsample': 0.4359122993757377, 'colsample_bylevel': 0.6326559961214083, 'min_data_in_leaf': 18}. Best is trial 7 with value: 0.7181391734387009.
# [I 2023-11-23 08:32:47,329] Trial 13 finished with value: 0.7300611245882154 and parameters: {'learning_rate': 0.486990460058908, 'depth': 15, 'subsample': 0.6342376255265277, 'colsample_bylevel': 0.6656602981518867, 'min_data_in_leaf': 22}. Best is trial 7 with value: 0.7181391734387009.
# [I 2023-11-23 08:33:22,112] Trial 14 finished with value: 0.811792027836249 and parameters: {'learning_rate': 0.07383278090456802, 'depth': 8, 'subsample': 0.23951023428755558, 'colsample_bylevel': 0.6256889754932635, 'min_data_in_leaf': 59}. Best is trial 7 with value: 0.7181391734387009.
# [I 2023-11-23 08:34:31,589] Trial 15 finished with value: 0.7200887394582551 and parameters: {'learning_rate': 0.2044602174217543, 'depth': 12, 'subsample': 0.48469033444737447, 'colsample_bylevel': 0.7491409735873052, 'min_data_in_leaf': 38}. Best is trial 7 with value: 0.7181391734387009.
# [I 2023-11-23 08:35:52,146] Trial 16 finished with value: 0.7292391308131634 and parameters: {'learning_rate': 0.4980020201057981, 'depth': 13, 'subsample': 0.6668297226331373, 'colsample_bylevel': 0.5672822786382239, 'min_data_in_leaf': 37}. Best is trial 7 with value: 0.7181391734387009.
# [I 2023-11-23 08:37:31,398] Trial 17 finished with value: 0.7574525763226756 and parameters: {'learning_rate': 0.05376776815681182, 'depth': 14, 'subsample': 0.46428336774904894, 'colsample_bylevel': 0.9295934118467607, 'min_data_in_leaf': 67}. Best is trial 7 with value: 0.7181391734387009.
# [I 2023-11-23 08:38:33,616] Trial 18 finished with value: 0.7431966703654204 and parameters: {'learning_rate': 0.1998959554455865, 'depth': 8, 'subsample': 0.7061187658009375, 'colsample_bylevel': 0.8258665155896836, 'min_data_in_leaf': 45}. Best is trial 7 with value: 0.7181391734387009.
# [I 2023-11-23 08:39:28,372] Trial 19 finished with value: 0.7940389592858141 and parameters: {'learning_rate': 0.05209531768863308, 'depth': 11, 'subsample': 0.5006054158342286, 'colsample_bylevel': 0.5401190901213216, 'min_data_in_leaf': 31}. Best is trial 7 with value: 0.7181391734387009.
# [I 2023-11-23 08:41:21,151] Trial 20 finished with value: 0.7226447308858523 and parameters: {'learning_rate': 0.1319802581473298, 'depth': 14, 'subsample': 0.7277491829332117, 'colsample_bylevel': 0.7250177567424221, 'min_data_in_leaf': 28}. Best is trial 7 with value: 0.7181391734387009.
# [I 2023-11-23 08:42:30,136] Trial 21 finished with value: 0.716271412449139 and parameters: {'learning_rate': 0.22238521383065482, 'depth': 13, 'subsample': 0.38963460301773684, 'colsample_bylevel': 0.7259849180924337, 'min_data_in_leaf': 19}. Best is trial 21 with value: 0.716271412449139.
# [I 2023-11-23 08:43:53,329] Trial 22 finished with value: 0.723022822562319 and parameters: {'learning_rate': 0.2318693793002158, 'depth': 13, 'subsample': 0.571375284156439, 'colsample_bylevel': 0.7080067290066245, 'min_data_in_leaf': 11}. Best is trial 21 with value: 0.716271412449139.
# [I 2023-11-23 08:45:50,182] Trial 23 finished with value: 0.715374956568049 and parameters: {'learning_rate': 0.29844759163525564, 'depth': 15, 'subsample': 0.44116710254766295, 'colsample_bylevel': 0.8200575737708942, 'min_data_in_leaf': 38}. Best is trial 23 with value: 0.715374956568049.
# [I 2023-11-23 08:47:47,570] Trial 24 finished with value: 0.71939980509057 and parameters: {'learning_rate': 0.3450817432850659, 'depth': 15, 'subsample': 0.429782512262187, 'colsample_bylevel': 0.8587110632904917, 'min_data_in_leaf': 25}. Best is trial 23 with value: 0.715374956568049.
# [I 2023-11-23 08:49:44,061] Trial 25 finished with value: 0.7228958179063739 and parameters: {'learning_rate': 0.12217638765499149, 'depth': 15, 'subsample': 0.3914832766331362, 'colsample_bylevel': 0.9077960264470972, 'min_data_in_leaf': 1}. Best is trial 23 with value: 0.715374956568049.
# [I 2023-11-23 08:51:35,803] Trial 26 finished with value: 0.7208769079063494 and parameters: {'learning_rate': 0.2990102662163219, 'depth': 14, 'subsample': 0.5287769949101088, 'colsample_bylevel': 0.9952916782765162, 'min_data_in_leaf': 10}. Best is trial 23 with value: 0.715374956568049.
# [I 2023-11-23 08:53:24,657] Trial 27 finished with value: 0.7450783968149187 and parameters: {'learning_rate': 0.07155147570214812, 'depth': 14, 'subsample': 0.608321341959651, 'colsample_bylevel': 0.8163496615944691, 'min_data_in_leaf': 40}. Best is trial 23 with value: 0.715374956568049.
# [I 2023-11-23 08:54:34,594] Trial 28 finished with value: 0.7236887307277535 and parameters: {'learning_rate': 0.13997439427744834, 'depth': 13, 'subsample': 0.5193797400530902, 'colsample_bylevel': 0.559042416983196, 'min_data_in_leaf': 34}. Best is trial 23 with value: 0.715374956568049.
# [I 2023-11-23 08:56:17,364] Trial 29 finished with value: 0.7215168071756064 and parameters: {'learning_rate': 0.2826936063932211, 'depth': 15, 'subsample': 0.396511355932127, 'colsample_bylevel': 0.6895328751863212, 'min_data_in_leaf': 49}. Best is trial 23 with value: 0.715374956568049.

# %%
print('Best hyperparameters:', study.best_params)
print('Best RMSE:', study.best_value)
# Out:
# Best hyperparameters: {'learning_rate': 0.29844759163525564, 'depth': 15, 'subsample': 0.44116710254766295, 'colsample_bylevel': 0.8200575737708942, 'min_data_in_leaf': 38}
# Best RMSE: 0.715374956568049

# %% [markdown]
# depth is again at the maximum. run again when time. try first with these hyperparams.

# %%
 #just to compare here again,
# params = {
#        "iterations": 100,
 #       "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.1, log=True),
  #      "depth": trial.suggest_int("depth", 1, 10),
   #     "subsample": trial.suggest_float("subsample", 0.05, 1.0),
    #    "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.05, 1.0),
     #   "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 1, 100),
    #}
    
#{'learning_rate': 0.09862076321051468, 'depth': 10, 'subsample': 0.5527953446670311, 
# 'colsample_bylevel': 0.7475725939379173, 'min_data_in_leaf': 58}

# -> adjust learning rate and depth
